# %% [markdown]
# <a href="https://colab.research.google.com/github/Elwing-Chou/tibame20251203/blob/main/tibame_20251222.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ```
#
# WIN: -headers "Origin: https://ani.gamer.com.tw" -i "" anime.mp4
#
# MAC: -headers 'Origin: https://ani.gamer.com.tw' -i '' anime.mp4
#
# cd xxx
# 可執行的程式 參數
# 1. 位置參數(放最後面, 一定會帶入的)
# 2. 告訴她參數拿來幹嗎
#    a. 短參數: -V               -短參數名 值
#    b. 長參數: --version        --長參數名 值
#
# ```

# %%
f = open("a.txt", "w", encoding="utf-8")
f.write("aaasss\nddddd")
f.close()

# %%
with open("a.txt", "w", encoding="utf-8") as f:
    f.write("aaasss\nddddd")

# %%
f = open("a.txt", "r", encoding="utf-8")
content = f.read()
f.close()
print(content)
# Out:
# aaasss
# ddddd

# %%
with open("a.txt", "r", encoding="utf-8") as f:
    content = f.read()
print(content)
# Out:
# aaasss
# ddddd

# %% [markdown]
# ```
# csv tsv
# (comma-separated values)
#
# name,height
# Elwing,175
# "E ,Mr. Chou",180
# ```

# %%
import json
import urllib.request as req

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
# print(type(content))
content = json.loads(content)
# print(type(content))
danmus = content["data"]["danmu"]

f = open("danmu.csv", "w", encoding="utf-8")
f.write("userid,text\n")
for d in danmus:
    d_uid = d["userid"]
    d_text = d["text"]
    # print(d_uid, d_text)
    pat = '{},"{}"\n'
    f.write(pat.format(d_uid, d_text))
f.close()

# %%
'"wsyrsyy"'
"""abc

def
"""
# Out:
# 'abc\n\ndef\n'

# %% [markdown]
# ```
#
# [{},{}]
#
# pd: DataFrame(2d) Series(1d)
# ```

# %%
import json
import urllib.request as req
import pandas as pd

url = "https://api.gamer.com.tw/anime/v1/danmu.php?videoSn=36632&geo=TW%2CHK"
f = req.urlopen(url)
content = f.read()
# print(type(content))
content = json.loads(content)
# print(type(content))
danmus = content["data"]["danmu"]
df = pd.DataFrame(danmus)
# index=False
df.to_csv("danmu.csv", encoding="utf-8")
df.to_excel("danmu.xlsx")
df
# Out:
#                     text    color  size  position  time        sn  \
# 0                     二刷  #FFFFFF     1         0     0  42903755
# 1                  吉伊卡哇！  #FFFFFF     1         0     0  45641971
# 2                 感謝動畫瘋！  #FFFFFF     1         0     0  45796240
# 3            2025.11.24簽  #FDE53D     1         0     0  47316552
# 4                  吉依好可愛  #FFFFFF     1         0     5  40580321
# ..                   ...      ...   ...       ...   ...       ...
# 524  ˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊˊ  #FFFFFF     1         0   893  46704569
# 525                    我  #FFFFFF     1         0   897  45779317
# 526                    😀  #00C3FC     1         0   898  40894473
# 527               沒了？？？？  #FFFFFF     1         0   901  42188563
# 528                    哈  #FF0026     1         0   901  44529579
#
#            userid
# 0      qaz1210731
# 1     dodylee0107
# 2          hyg125
# 3      MilkTea157
# 4    KingOrange69
# ..            ...
# 524         swyan
# ...

# %%
import urllib.request as request
import urllib.parse as parse

url = 'https://www.thsrc.com.tw/TimeTable/Search'
# Data to be sent (dictionary, list of tuples, etc.)
data = {
    "SearchType":"S",
    "Lang":"TW",
    "StartStation":"NanGang",
    "EndStation":"ZuoYing",
    "OutWardSearchDate":"2025/12/22",
    "OutWardSearchTime":"14:30",
    "ReturnSearchDate":"2025/12/22",
    "ReturnSearchTime":"14:30",
    "DiscountType":"",
}

# Encode the data into the standard format and then to bytes
encoded_data = parse.urlencode(data).encode('utf-8')
resp = request.urlopen(url, encoded_data)
resp.read()

# %%
import datetime as dt
dt.date.today()
# Out:
# datetime.date(2025, 12, 22)
